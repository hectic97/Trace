# %%
import requests
from bs4 import BeautifulSoup

# %%
test_url = 'https://movie.daum.net/boxoffice/yearly?year=2005'
resp = requests.get(test_url)
html3 = BeautifulSoup(resp.content, 'html.parser')
html3
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="Daum 영화" property="og:site_name"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- <title>$tagfilter.filter($stringCutUtil.cutStringRealLength($tmp, $len, "..")) - Daum 영화</title> -->
# <title>박스오피스 | 다음영화</title>
# <meta content="이번주 박스오피스 1위는?" property="og:title"/>
# <meta content="http://t1.daumcdn.net/movie/common/og_default.png" property="og:image"/>
# <meta content="Daum영화에서 자세한 내용을 확인하세요!" property="og:description"/>
# <meta content="" name="plink">
# <meta content="" property="dg:plink">
# <meta content="" property="article:mobile_view_url"> <!-- mobile -->
# <meta content="" property="article:pc_view_url"> <!-- pc -->
# <meta content="" property="article:mobile_url"> <!-- mobile -->
# <meta content="" property="article:pc_url"> <!-- pc -->
# <meta content="" name="article:media_name"/>
# ...

# %%
st=str(lis[7])
st2=st[st.find('href=')+6:]
st3=st2[:st2.find('>')-1]
new_url='https://movie.daum.net/'+st3
new_url
res=requests.get(new_url)
html2=BeautifulSoup(res.content,'html.parser')

lis2=html2.find('div',{'class':'movie_summary'})
# html2
lis3=html2.findAll('a',{'class':'link_person #info #name'})

# %%
nurl='https://movie.daum.net/moviedb/main?movieId=39208'
res=requests.get(nurl)
html=BeautifulSoup(res.content,'html.parser')
html.findAll('dd',{'class':'type_ellipsis'})[1].findAll('a')
# Out:
# [<a class="link_person #info #name" href="/person/main?personId=94005">바이쇼 치에코</a>,
#  <a class="link_person #info #name" href="/person/main?personId=2655">기무라 타쿠야</a>]

# %%
html2.findAll('dd')[4]
# Out:
# <dd class="type_ellipsis">(감독)
# 																					<a class="link_person #info #name" href="/person/main?personId=30669">앤드류 아담슨</a>, 																					<a class="link_person #info #name" href="/person/main?personId=44256">켈리 애스버리</a>, 																					<a class="link_person #info #name" href="/person/main?personId=77136">콘래드 버논</a> </dd>

# %%
lst=[]
lst.append([x.getText() for x in html2.findAll('dd')[5].findAll('a')])
lst
# Out:
# [['마이크 마이어스', '에디 머피', '카메론 디아즈']]

# %%
html3
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="Daum 영화" property="og:site_name"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- <title>$tagfilter.filter($stringCutUtil.cutStringRealLength($tmp, $len, "..")) - Daum 영화</title> -->
# <title>박스오피스 | 다음영화</title>
# <meta content="이번주 박스오피스 1위는?" property="og:title"/>
# <meta content="http://t1.daumcdn.net/movie/common/og_default.png" property="og:image"/>
# <meta content="Daum영화에서 자세한 내용을 확인하세요!" property="og:description"/>
# <meta content="" name="plink">
# <meta content="" property="dg:plink">
# <meta content="" property="article:mobile_view_url"> <!-- mobile -->
# <meta content="" property="article:pc_view_url"> <!-- pc -->
# <meta content="" property="article:mobile_url"> <!-- mobile -->
# <meta content="" property="article:pc_url"> <!-- pc -->
# <meta content="" name="article:media_name"/>
# ...

# %%
html3.findAll('dd')[4].find('a').getText()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-279-31294b4cd843> in <module>
# ----> 1 html3.findAll('dd')[4].find('a').getText()
#
# AttributeError: 'NoneType' object has no attribute 'getText'

# %%
lis2.findAll('dd')[0].getText()
# Out:
# '액션/로맨스/멜로'

# %%
name_html = html.find('div', {'class': 'main_detail'})
lis = name_html.findAll('li')
for li in lis:
    print(li.find('strong').getText())
# Out:
# 태극기 휘날리며
# 트로이
# 내 머리 속의 지우개
# 귀신이 산다
# 투모로우
# 우리 형
# 해리포터와 아즈카반의 죄수
# 슈렉2
# 실미도
# 스파이더맨 2
# 바람의 파이터
# 오페라의 유령
# 내 여자친구를 소개합니다
# 늑대의 유혹
# 가족
# 시실리 2km
# 아이, 로봇
# S 다이어리
# 알포인트
# 주홍글씨
# 연인
# 브리짓 존스의 일기2 : 열정과 애정
# 어린 신부
# 터미널
# 하울의 움직이는 성
# 나비효과
# 역도산
# 범죄의 재구성
# 반 헬싱
# 이프 온리
# 여선생 VS 여제자
# 패션 오브 크라이스트
# 아라한 장풍대작전
# 킹 아더
# 내 남자의 로맨스
# 효자동 이발사
# 아는 여자
# 달마야, 서울 가자
# 신부수업
# 블레이드 3
# 슈퍼스타 감사용
# 인크레더블
# 분신사바
# 말죽거리 잔혹사
# 콜래트럴
# 투 가이즈
# 령
# 돈 텔 파파
# 누구나 비밀은 있다
# 꽃피는 봄이 오면

# %%
movie_name=lis[0].find('span').getText()
movie_name
# Out:
# '1위'

# %%
lis[0].find('strong').getText()
# Out:
# '태극기 휘날리며'

# %%
lis[0].find('em').getText()
# Out:
# '9.1'

# %%
lis[0].find('dd').getText()
# Out:
# '2004.02.05 개봉'

# %%
lis[0].find('dd').getText()[:4]+'년'+lis[0]
# Out:
# '2004'

# %%
img=str(lis[0].find('img'))
img[img.find('http'):img.find('onload')-2]
# Out:
# 'http://cfile89.uf.daum.net/image/11110210A90B2ABFE8C6CE'

# %%
newstr=str(img)[(str(img).find(':')-4):]
img_link=newstr[:newstr.find(' ')-1]
# urllib.request.urlretrieve(img_link,"./img2.png")
urllib.request.urlretrieve(img_link,"./image/2014.png")
# Out:
# ('./image/2014.png', <http.client.HTTPMessage at 0x170c7170748>)

# %%
# https://movie.daum.net/boxoffice/yearly?year=2004
#     img1.daumcdn.net/thumb/R338x491/?fname=http://cfile89.uf.daum.net/image/11110210A90B2ABFE8C6CE
import requests

url ="https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Wikipedia-logo-v2.svg/150px-Wikipedia-logo-v2.svg.png"

r = requests.get(url)
file = open("wiki_logo.jpg","wb")
file.write(r.content)
file.close()

print("파일을 생성하였습니다.")
# Out:
# ''

# %%
def get_info(year):
    url = 'https://movie.daum.net/boxoffice/yearly?year='+str(year)
    response = requests.get(url)
    html = BeautifulSoup(response.content, 'html.parser')
    detail = html.find('div',{'class': 'main_detail'})
    lis = name_html.findAll('li')
    lis[0]

# %%
# Out:
# 'https://movie.daum.net/boxoffice/yearly?year=2004'
