# %%
import numpy as np
def reweight_distribution(original_distribution,temperature=0.5):
    distribution = np.log(original_distribution)/temperature
    distribution = np.exp(distribution)
    return distribution/np.sum(distribution)

# %%
import keras
import numpy as np

path=keras.utils.get_file('nietzsche.txt',origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:',len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 3s 5us/step
# 말뭉치 크기: 600893

# %%
text[:10]
# Out:
# 'preface\n\n\n'

# %%
text2=open(r'C:/Users/집/data/KakaoTalk_20200303_2134_34_335_group.txt',encoding='UTF8').read()
text3=open(r'C:/Users/집/data/KakaoTalk_20200303_2144_25_150_장윤호.txt',encoding='UTF8').read()

# %%
import re
# print(text3[:300])
# print('##############')
# # print(re.sub(r'\[[^)]*\]', '', text3[:300]))

# a=(re.sub('\\[(.*?)\\]','',text3[:5000]))
# b=re.sub('\-(.*?)\-','',a)
# print(b)
text3=re.sub('\-(.*?)\-','',re.sub('\\[(.*?)\\]','',text3))

# %%
text3=text3.replace('\n','')

# %%
text3=text3.replace('  ',' ')

# %%
maxlen=60
step =3
sentences=[]
next_chars=[]

for i in range(0,len(text3)-maxlen,step):
    sentences.append(text3[i:i+maxlen])
    next_chars.append(text3[i+maxlen])
    print('Sequence:',len(sentences))
    
    chars=sorted(list(set(text3)))
    print('Unique:',len(chars))
    char_indices = dict((char,chars.index(char)) for char in chars)
    print('Vectorization')
    
    x=np.zeros((len(sentences),maxlen,len(chars)),dtype=np.bool)
    y=np.zeros((len(sentences),len(chars)),dtype=np.bool)
    
    for i,sentence in enumerate(sentences):
        for t,char in enumerate(sentence):
            for t,char in enumerate(sentence):
                x[i,t,char_indices[char]]=1
            y[i,char_indices[next_chars[i]]]=1
# Out:
# Sequence: 1
# Unique: 1614
# Vectorization
# Sequence: 2
# Unique: 1614
# Vectorization
# Sequence: 3
# Unique: 1614
# Vectorization
# Sequence: 4
# Unique: 1614
# Vectorization
# Sequence: 5
# Unique: 1614
# Vectorization
# Sequence: 6
# Unique: 1614
# Vectorization
# Sequence: 7
# Unique: 1614
# Vectorization
# Sequence: 8
# Unique: 1614
# Vectorization
# Sequence: 9
# Unique: 1614
# Vectorization
# Sequence: 10
# Unique: 1614
# Vectorization
# Sequence: 11
# Unique: 1614
# Vectorization
# Sequence: 12
# Unique: 1614
# Vectorization
# Sequence: 13
# Unique: 1614
# Vectorization
# Sequence: 14
# Unique: 1614
# Vectorization
# Sequence: 15
# Unique: 1614
# Vectorization
# Sequence: 16
# Unique: 1614
# Vectorization
# Sequence: 17
# Unique: 1614
# Vectorization
# Sequence: 18
# Unique: 1614
# Vectorization
# Sequence: 19
# Unique: 1614
# Vectorization
# Sequence: 20
# Unique: 1614
# Vectorization
# Sequence: 21
# Unique: 1614
# Vectorization
# Sequence: 22
# Unique: 1614
# Vectorization
# Sequence: 23
# Unique: 1614
# Vectorization
# Sequence: 24
# Unique: 1614
# Vectorization
# Sequence: 25
# Unique: 1614
# Vectorization
# Sequence: 26
# Unique: 1614
# Vectorization
# Sequence: 27
# Unique: 1614
# Vectorization
# Sequence: 28
# Unique: 1614
# Vectorization
# Sequence: 29
# Unique: 1614
# Vectorization
# Sequence: 30
# Unique: 1614
# Vectorization
# Sequence: 31
# Unique: 1614
# Vectorization
# Sequence: 32
# Unique: 1614
# Vectorization
# Sequence: 33
# Unique: 1614
# Vectorization
# Sequence: 34
# Unique: 1614
# Vectorization
# Sequence: 35
# Unique: 1614
# Vectorization
# Sequence: 36
# Unique: 1614
# Vectorization
# Sequence: 37
# Unique: 1614
# Vectorization
# Sequence: 38
# Unique: 1614
# Vectorization
# Sequence: 39
# Unique: 1614
# Vectorization
# Sequence: 40
# Unique: 1614
# Vectorization
# Sequence: 41
# Unique: 1614
# Vectorization
# Sequence: 42
# Unique: 1614
# Vectorization
# Sequence: 43
# Unique: 1614
# Vectorization
# Sequence: 44
# Unique: 1614
# Vectorization
# Sequence: 45
# Unique: 1614
# Vectorization
# Sequence: 46
# Unique: 1614
# Vectorization
# Sequence: 47
# Unique: 1614
# Vectorization
# Sequence: 48
# Unique: 1614
# Vectorization
# Sequence: 49
# Unique: 1614
# Vectorization
# Sequence: 50
# Unique: 1614
# Vectorization
# Sequence: 51
# Unique: 1614
# Vectorization
# Sequence: 52
# Unique: 1614
# Vectorization
# Sequence: 53
# Unique: 1614
# Vectorization
# Sequence: 54
# Unique: 1614
# Vectorization
# Sequence: 55
# Unique: 1614
# Vectorization
# Sequence: 56
# Unique: 1614
# Vectorization
# Sequence: 57
# Unique: 1614
# Vectorization
# Sequence: 58
# Unique: 1614
# Vectorization
# Sequence: 59
# Unique: 1614
# Vectorization
# Sequence: 60
# Unique: 1614
# Vectorization
# Sequence: 61
# Unique: 1614
# Vectorization
# Sequence: 62
# Unique: 1614
# Vectorization
# Sequence: 63
# Unique: 1614
# Vectorization
# Sequence: 64
# Unique: 1614
# Vectorization
# Sequence: 65
# Unique: 1614
# Vectorization
# Sequence: 66
# Unique: 1614
# Vectorization
# Sequence: 67
# Unique: 1614
# Vectorization
# Sequence: 68
# Unique: 1614
# Vectorization
# Sequence: 69
# Unique: 1614
# Vectorization
# Sequence: 70
# Unique: 1614
# Vectorization
# Sequence: 71
# Unique: 1614
# Vectorization
# Sequence: 72
# Unique: 1614
# Vectorization
# Sequence: 73
# Unique: 1614
# Vectorization
# Sequence: 74
# Unique: 1614
# Vectorization
# Sequence: 75
# Unique: 1614
# Vectorization
# Sequence: 76
# Unique: 1614
# Vectorization
# Sequence: 77
# Unique: 1614
# Vectorization
# Sequence: 78
# Unique: 1614
# Vectorization
# Sequence: 79
# Unique: 1614
# Vectorization
# Sequence: 80
# Unique: 1614
# Vectorization
# Sequence: 81
# Unique: 1614
# Vectorization
# Sequence: 82
# Unique: 1614
# Vectorization
# Sequence: 83
# Unique: 1614
# Vectorization
# Sequence: 84
# Unique: 1614
# Vectorization
# Sequence: 85
# Unique: 1614
# Vectorization
# Sequence: 86
# Unique: 1614
# Vectorization
# Sequence: 87
# Unique: 1614
# Vectorization
# Sequence: 88
# Unique: 1614
# Vectorization
# Sequence: 89
# Unique: 1614
# Vectorization
# Sequence: 90
# Unique: 1614
# Vectorization
# Sequence: 91
# Unique: 1614
# Vectorization
# Sequence: 92
# Unique: 1614
# Vectorization
# Sequence: 93
# Unique: 1614
# Vectorization
# Sequence: 94
# Unique: 1614
# Vectorization
# Sequence: 95
# Unique: 1614
# Vectorization
# Sequence: 96
# Unique: 1614
# Vectorization
# Sequence: 97
# Unique: 1614
# Vectorization
# Sequence: 98
# Unique: 1614
# Vectorization
# Sequence: 99
# Unique: 1614
# Vectorization
# Sequence: 100
# Unique: 1614
# Vectorization
# Sequence: 101
# Unique: 1614
# Vectorization
# Sequence: 102
# Unique: 1614
# Vectorization
# Sequence: 103
# Unique: 1614
# Vectorization
# Sequence: 104
# Unique: 1614
# Vectorization
# Sequence: 105
# Unique: 1614
# Vectorization
# Sequence: 106
# Unique: 1614
# Vectorization
# Sequence: 107
# Unique: 1614
# Vectorization
# Sequence: 108
# Unique: 1614
# Vectorization
# Sequence: 109
# Unique: 1614
# Vectorization
# Sequence: 110
# Unique: 1614
# Vectorization
# Sequence: 111
# Unique: 1614
# Vectorization
# Sequence: 112
# Unique: 1614
# Vectorization
# Sequence: 113
# Unique: 1614
# Vectorization
# Sequence: 114
# Unique: 1614
# Vectorization
# Sequence: 115
# Unique: 1614
# Vectorization
# Sequence: 116
# Unique: 1614
# Vectorization
# Sequence: 117
# Unique: 1614
# Vectorization
# Sequence: 118
# Unique: 1614
# Vectorization
# Sequence: 119
# Unique: 1614
# Vectorization
# Sequence: 120
# Unique: 1614
# Vectorization
# Sequence: 121
# Unique: 1614
# Vectorization
# Sequence: 122
# Unique: 1614
# Vectorization
# Sequence: 123
# Unique: 1614
# Vectorization
# Sequence: 124
# Unique: 1614
# Vectorization
# Sequence: 125
# Unique: 1614
# Vectorization
# Sequence: 126
# Unique: 1614
# Vectorization
# Sequence: 127
# Unique: 1614
# Vectorization
# Sequence: 128
# Unique: 1614
# Vectorization
# Sequence: 129
# Unique: 1614
# Vectorization
# Sequence: 130
# Unique: 1614
# Vectorization
# Sequence: 131
# Unique: 1614
# Vectorization
# Sequence: 132
# Unique: 1614
# Vectorization
# Sequence: 133
# Unique: 1614
# Vectorization
# Sequence: 134
# Unique: 1614
# Vectorization
# Sequence: 135
# Unique: 1614
# Vectorization
# Sequence: 136
# Unique: 1614
# Vectorization
# Sequence: 137
# Unique: 1614
# Vectorization
# Sequence: 138
# Unique: 1614
# Vectorization
# Sequence: 139
# Unique: 1614
# Vectorization
# Sequence: 140
# Unique: 1614
# Vectorization
# Sequence: 141
# Unique: 1614
# Vectorization
# Sequence: 142
# Unique: 1614
# Vectorization
# Sequence: 143
# Unique: 1614
# Vectorization
# Sequence: 144
# Unique: 1614
# Vectorization
# Sequence: 145
# Unique: 1614
# Vectorization
# Sequence: 146
# Unique: 1614
# Vectorization
# Sequence: 147
# Unique: 1614
# Vectorization
# Sequence: 148
# Unique: 1614
# Vectorization
# Sequence: 149
# Unique: 1614
# Vectorization
# Sequence: 150
# Unique: 1614
# Vectorization
# Sequence: 151
# Unique: 1614
# Vectorization
# Sequence: 152
# Unique: 1614
# Vectorization
# Sequence: 153
# Unique: 1614
# Vectorization
# Sequence: 154
# Unique: 1614
# Vectorization
# Sequence: 155
# Unique: 1614
# Vectorization
# Sequence: 156
# Unique: 1614
# Vectorization
# Sequence: 157
# Unique: 1614
# Vectorization
# Sequence: 158
# Unique: 1614
# Vectorization
# Sequence: 159
# Unique: 1614
# Vectorization
# Sequence: 160
# Unique: 1614
# Vectorization
# Sequence: 161
# Unique: 1614
# Vectorization
# Sequence: 162
# Unique: 1614
# Vectorization
# Sequence: 163
# Unique: 1614
# Vectorization
# Sequence: 164
# Unique: 1614
# Vectorization
# Sequence: 165
# Unique: 1614
# Vectorization
# Sequence: 166
# Unique: 1614
# Vectorization
# Sequence: 167
# Unique: 1614
# Vectorization
# Sequence: 168
# Unique: 1614
# Vectorization
# Sequence: 169
# Unique: 1614
# Vectorization
# Sequence: 170
# Unique: 1614
# Vectorization
# Sequence: 171
# Unique: 1614
# Vectorization
# Sequence: 172
# Unique: 1614
# Vectorization
# Sequence: 173
# Unique: 1614
# Vectorization
# Sequence: 174
# Unique: 1614
# Vectorization
# Sequence: 175
# Unique: 1614
# Vectorization
# Sequence: 176
# Unique: 1614
# Vectorization
# Sequence: 177
# Unique: 1614
# Vectorization
# Sequence: 178
# Unique: 1614
# Vectorization
# Sequence: 179
# Unique: 1614
# Vectorization
# Sequence: 180
# Unique: 1614
# Vectorization
# Sequence: 181
# Unique: 1614
# Vectorization
# Sequence: 182
# Unique: 1614
# Vectorization
# Sequence: 183
# Unique: 1614
# Vectorization
# Sequence: 184
# Unique: 1614
# Vectorization
# Sequence: 185
# Unique: 1614
# Vectorization
# Sequence: 186
# Unique: 1614
# Vectorization
# Sequence: 187
# Unique: 1614
# Vectorization
# Sequence: 188
# Unique: 1614
# Vectorization
# Sequence: 189
# Unique: 1614
# Vectorization
# Sequence: 190
# Unique: 1614
# Vectorization
# Sequence: 191
# Unique: 1614
# Vectorization
# Sequence: 192
# Unique: 1614
# Vectorization
# Sequence: 193
# Unique: 1614
# Vectorization
# Sequence: 194
# Unique: 1614
# Vectorization
# Sequence: 195
# Unique: 1614
# Vectorization
# Sequence: 196
# Unique: 1614
# Vectorization
# Sequence: 197
# Unique: 1614
# Vectorization
# Sequence: 198
# Unique: 1614
# Vectorization
# Sequence: 199
# Unique: 1614
# Vectorization
# Sequence: 200
# Unique: 1614
# Vectorization
# Sequence: 201
# Unique: 1614
# Vectorization
# Sequence: 202
# Unique: 1614
# Vectorization
# Sequence: 203
# Unique: 1614
# Vectorization
# Sequence: 204
# Unique: 1614
# Vectorization
# Sequence: 205
# Unique: 1614
# Vectorization
# Sequence: 206
# Unique: 1614
# Vectorization
# Sequence: 207
# Unique: 1614
# Vectorization
# Sequence: 208
# Unique: 1614
# Vectorization
# Sequence: 209
# Unique: 1614
# Vectorization
# Sequence: 210
# Unique: 1614
# Vectorization
# Sequence: 211
# Unique: 1614
# Vectorization
# Sequence: 212
# Unique: 1614
# Vectorization
# Sequence: 213
# Unique: 1614
# Vectorization
# Sequence: 214
# Unique: 1614
# Vectorization
# Sequence: 215
# Unique: 1614
# Vectorization
# Sequence: 216
# Unique: 1614
# Vectorization
# Sequence: 217
# Unique: 1614
# Vectorization
# Sequence: 218
# Unique: 1614
# Vectorization
# Sequence: 219
# Unique: 1614
# Vectorization
# Sequence: 220
# Unique: 1614
# Vectorization
# Sequence: 221
# Unique: 1614
# Vectorization
# Sequence: 222
# Unique: 1614
# Vectorization
# Sequence: 223
# Unique: 1614
# Vectorization
# Sequence: 224
# Unique: 1614
# Vectorization
# Sequence: 225
# Unique: 1614
# Vectorization
# Sequence: 226
# Unique: 1614
# Vectorization
# Sequence: 227
# Unique: 1614
# Vectorization
# Sequence: 228
# Unique: 1614
# Vectorization
# Sequence: 229
# Unique: 1614
# Vectorization
# Sequence: 230
# Unique: 1614
# Vectorization
# Sequence: 231
# Unique: 1614
# Vectorization
# Sequence: 232
# Unique: 1614
# Vectorization
# Sequence: 233
# Unique: 1614
# Vectorization
# Sequence: 234
# Unique: 1614
# Vectorization
# Sequence: 235
# Unique: 1614
# Vectorization
# Sequence: 236
# Unique: 1614
# Vectorization
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-9318fe3b14f5> in <module>
#      20         for t,char in enumerate(sentence):
#      21             for t,char in enumerate(sentence):
# ---> 22                 x[i,t,char_indices[char]]=1
#      23             y[i,char_indices[next_chars[i]]]=1
#
# KeyboardInterrupt:
