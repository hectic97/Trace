# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../input/glasses/glass.data',header=None)

# %%
'''
1. Id number: 1 to 214
2. RI: refractive index
3. Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
4. Mg: Magnesium
5. Al: Aluminum
6. Si: Silicon
7. K: Potassium
8. Ca: Calcium
9. Ba: Barium
10. Fe: Iron
11. Type of glass: (class attribute)
-- 1 building_windows_float_processed
-- 2 building_windows_non_float_processed
-- 3 vehicle_windows_float_processed
-- 4 vehicle_windows_non_float_processed (none in this database)
-- 5 containers
-- 6 tableware
-- 7 headlamps
'''

# %%
data.drop(0,axis=1,inplace=True)

# %%
data.columns = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','class']
data.head()

# %%
from sklearn.preprocessing import StandardScaler
x = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
scaler = StandardScaler()
scaler.fit(x)
x_scaled = scaler.transform(x)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(x_scaled)
x_scaled_pca = pca.transform(x_scaled)
pca.fit(x)
x_pca = pca.transform(x)

# %%
print('Original shape: ',x_scaled.shape)
print('Reduced shape: ',x_scaled_pca.shape)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax = plt.subplots(1,2,figsize=(20,10))
sns.scatterplot(x=x_scaled_pca[:,0],y=x_scaled_pca[:,1],hue=y,palette='muted',ax=ax[0])
sns.scatterplot(x=x_pca[:,0],y=x_pca[:,1],hue=y,palette='muted',ax=ax[1])
ax[0].set_title('scaled pca')
ax[1].set_title('pca')
plt.legend()
plt.show()

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state=1115)

x_scaled_tsne = tsne.fit_transform(x_scaled)
x_tsne = tsne.fit_transform(x)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
sns.scatterplot(x=x_scaled_tsne[:,0],y=x_scaled_tsne[:,1],hue=y,palette='muted',ax=ax[0])
sns.scatterplot(x=x_tsne[:,0],y=x_tsne[:,1],hue=y,palette='muted',ax=ax[1])
ax[0].set_title('scaled tsne')
ax[1].set_title('tsne')
plt.legend()
plt.show()
