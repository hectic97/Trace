# %%
import numpy as np
import tensorflow as tf

# %%
def min_max_scaler(data):
    numerator=data-np.min(data,axis=0)
    denominator=np.max(data,axis=0)-np.min(data,axis=0)
    return numerator/denominator

# %%
xy = np.array([[828.659973, 833.450012, 908100, 828.349976, 831.659973],
               [823.02002, 828.070007, 1828100, 821.655029, 828.070007],
               [819.929993, 824.400024, 1438100, 818.97998, 824.159973],
               [816, 820.958984, 1008100, 815.48999, 819.23999],
               [819.359985, 823, 1188100, 818.469971, 818.97998],
               [819, 823, 1198100, 816, 820.450012],
               [811.700012, 815.25, 1098100, 809.780029, 813.669983],
               [809.51001, 816.659973, 1398100, 804.539978, 809.559998]])

# %%
tf.model=tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim =4))
tf.model.add(tf.keras.layers.Activation('linear'))
tf.model.compile(loss='mse',optimizers=tf.keras.optimizers.SGD(lr=1e-5))
tf.model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 1)                 5
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# ...
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
xy=min_max_scaler(xy)  # If not scaling  loss 97000000
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

# %%
history = tf.model.fit(x_data, y_data, epochs=400)

predictions = tf.model.predict(x_data)
score = tf.model.evaluate(x_data, y_data)

print('Prediction: \n', predictions)
print('Cost: ', score)
# Out:
# Train on 8 samples
# Epoch 1/400
# 8/8 [==============================] - 0s 5ms/sample - loss: 0.0807
# Epoch 2/400
# 8/8 [==============================] - 0s 2ms/sample - loss: 0.0807
# Epoch 3/400
# 8/8 [==============================] - 0s 0s/sample - loss: 0.0807
# Epoch 4/400
# 8/8 [==============================] - 0s 375us/sample - loss: 0.0807
# Epoch 5/400
# 8/8 [==============================] - 0s 625us/sample - loss: 0.0807
# Epoch 6/400
# 8/8 [==============================] - 0s 250us/sample - loss: 0.0807
# Epoch 7/400
# 8/8 [==============================] - 0s 375us/sample - loss: 0.0807
# Epoch 8/400
# 8/8 [==============================] - 0s 375us/sample - loss: 0.0807
# Epoch 9/400
# 8/8 [==============================] - 0s 375us/sample - loss: 0.0807
# Epoch 10/400
# 8/8 [==============================] - 0s 500us/sample - loss: 0.0807
# Epoch 11/400
# 8/8 [==============================] - 0s 375us/sample - loss: 0.0807
# Epoch 12/400
# ...
